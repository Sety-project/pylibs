# %%
from jupyter_imports import *
from copy import deepcopy
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# run only once
from utils.MyLogger import ExecutionLogger # use 'prod' for remote after cache_tmp
start = datetime(2022,6,28,18)#,tzinfo=timezone.utc)
dirname = os.path.join(os.sep, 'tmp','prod','tradeexecutor')#,'prod')
ExecutionLogger.batch_summarize_exec_logs(dirname,start=start,add_history_context=False,rebuild=True)
# Out:
# moved 0 logs to unreadable
# printed summaries to /tmp/prod/tradeexecutor

# %%
files = ['all_by_clientOrderId','all_by_coin','all_by_symbol','all_parameters','all_request','all_data']
original = {file:pd.read_csv(os.path.join(os.sep, dirname,f'{file}.csv'),parse_dates=['log_time'],index_col=0).sort_values('log_time') for file in files}

# %% [markdown]
# ## parameters for reference

# %%
all_parameters = original['all_parameters'].sort_values('log_time')
all_parameters = all_parameters[all_parameters['index']!='inception_time']
all_parameters['hash'] = all_parameters['log_time'].apply(lambda x: pd.util.hash_pandas_object(all_parameters.groupby('log_time').get_group(x).drop(columns=['log_time']).astype(str)).sum())
all_parameters['param_index'] = all_parameters['hash'].apply(lambda h: list(all_parameters['hash'].unique()).index(h))
all_parameters.drop(columns=['hash'],inplace=True)
param_map = all_parameters.set_index('log_time')['param_index'].to_dict()

# %%
indexed = deepcopy(original)
for df in indexed.values():
    df['param_index'] = df['log_time'].apply(lambda x:param_map[x])
#colors = matplotlib.cm.rainbow(np.linspace(0, 1, len(all_parameters['param_index'].unique())))

# %%
i=max(param_map.values())
indexed = {key:df[df['param_index']==i] for key,df in indexed.items()}
temp = all_parameters[(all_parameters['param_index']==i)&(all_parameters['index']!='comment')].drop(columns=['log_time'])
print(temp.head(temp['index'].nunique()).set_index('index'))
# Out:
#                                      0  param_index
# index
# rush_tolerance                      -1            4
# check_frequency                     60            4
# stop_tolerance                     2.0            4
# edit_trigger_tolerance             1.0            4
# aggressive_edit_price_tolerance      2            4
# edit_price_tolerance              0.25            4
# stdev_window                      3600            4
# entry_tolerance                    1.1            4
# max_cache_size                   10000            4
# global_beta                        0.7            4
# slice_factor                         1            4
# time_budget                        600            4
# significance_threshold            0.05            4
# max_nb_coins                         2            4
# delta_limit                       0.25            4
# message_cache_size                1000            4

# %% [markdown]
# ### slippage, fees in bps. filled in USD

# %%
by_symbol = indexed['all_by_symbol']
by_symbol = by_symbol[by_symbol['log_time']>start.replace(tzinfo=timezone.utc)]
by_symbol['absFilled'] = by_symbol['filledUSD'].apply(np.abs)
by_symbol['total_bps'] = by_symbol['slippage_bps'] + by_symbol['fee']
by_symbol['fee_USD'] = by_symbol['fee']*by_symbol['absFilled']/10000 # in bps for by_symbol, in USD for by_clientorderid :(
by_symbol['slippage_USD'] = by_symbol['slippage_bps']*by_symbol['absFilled']/10000
by_symbol['total_USD'] = by_symbol['total_bps']*by_symbol['absFilled']/10000

# %%
df_symbol = by_symbol[by_symbol['index']=='average'].pivot_table(index='log_time',aggfunc=sum)
df_symbol[['fee_USD','slippage_USD','total_USD']] /= 10000*by_symbol[by_symbol['index']=='average'].pivot_table(index='log_time',values=['absFilled'],aggfunc=sum).values

# %%
#ax.plot(df, c=df['param_index'], s=120, cmap=cmap, edgecolor='None',figsize=(20,10))
#plt.show()
display = df_symbol[['fee_USD','total_USD','absFilled']]
display.plot.bar(secondary_y='absFilled',figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='log_time'>

# %% [markdown]
# ### slippage distribution

# %%
print(by_symbol[['total_bps','fee']].describe())
print('total abs filled = {}'.format(by_symbol['absFilled'].sum()))
print('weighted_avg = {}'.format((by_symbol['total_bps']*by_symbol['absFilled']).sum()/by_symbol['absFilled'].sum()))
by_symbol.loc[by_symbol['index']=='average','total_bps'].hist(figsize=(10,5))
# Out:
#        total_bps   fee
# count  38.000000  38.0
# mean    3.088375   0.0
# std    23.052599   0.0
# min   -47.923323   0.0
# 25%   -14.710225   0.0
# 50%     3.655518   0.0
# 75%    19.797244   0.0
# max    59.198689   0.0
# total abs filled = 3030.3968999999997
# weighted_avg = -0.3888415368880499
# <AxesSubplot:>

# %%
by_coin = indexed['all_by_coin']
print(by_coin[['premium_vs_inception_bps','perleg_fee_bps']].describe())
trackrecord = by_coin[by_coin['index']=='average'].pivot_table(index='log_time',values=['perleg_fee_bps','perleg_filled_USD','premium_vs_inception_bps'],aggfunc=np.mean)
trackrecord.plot.bar(secondary_y='perleg_filled_USD',figsize=(20,10))
# Out:
#        premium_vs_inception_bps  perleg_fee_bps
# count                 29.000000            29.0
# mean                   9.306165             0.0
# std                   34.195206             0.0
# min                  -58.377116             0.0
# 25%                  -14.192168             0.0
# 50%                    7.686266             0.0
# 75%                   16.830500             0.0
# max                  118.397378             0.0
# <AxesSubplot:xlabel='log_time'>

# %% [markdown]
# # latency

# %%
by_clientOrderId = indexed['all_by_clientOrderId']
tick_to_order_local = by_clientOrderId[['tick_to_order_local']]
print(tick_to_order_local.describe())
upper = tick_to_order_local.quantile(q=0.95)
tick_to_order_local.clip(upper=upper,axis=1).hist(bins=50,figsize=(10,5))
# Out:
#        tick_to_order_local
# count            44.000000
# mean            181.191240
# std             144.676815
# min              88.359131
# 25%             112.601013
# 50%             133.310059
# 75%             148.333984
# max             642.561768
# array([[<AxesSubplot:title={'center':'tick_to_order_local'}>]],
#       dtype=object)

# %%
round_trip = pd.DataFrame(columns=['round_trip'], data = 2*(indexed['all_data']['timestamp']-indexed['all_data']['remote_timestamp']))
print(round_trip.describe())
upper = round_trip.quantile(q=0.95)
round_trip.clip(upper=upper,axis=1).hist(bins=50,figsize=(20,10))
# Out:
#         round_trip
# count  1256.000000
# mean     56.029690
# std     124.856335
# min       0.006348
# 25%       0.029785
# 50%      31.572998
# 75%      68.203247
# max    2702.069824
# array([[<AxesSubplot:title={'center':'round_trip'}>]], dtype=object)
